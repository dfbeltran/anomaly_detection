# %% [markdown]
# # Purchase Card Transactions - Anomaly Detection
#
# Birmingham City Council is the local government body responsible for the governance of the City of Birmingham in England. For them transparency is one of the main values they want to reflect and with open data initiatives they give access to be freely used, reused and redistributed by anyone. That's why they started publishing all corporate purchase of card transactions since Apr 2014 until date,  our main goal will be to audit through an unsupervised machine learning algorithm if there is any anomaly present in the information that is exposed.
#
# Anomaly detection is an important tool for detecting fraud, network intrusion or rare events that may have impact but are hard to identify. In this notebook we will use anomaly detection to finding patterns in data that don’t conform to a model of normal behavior for the corporate purchase of card (if any).
#
# We will use the Framework of Microsoft Team Data Science Process (TDSP) and the Data science steps for ML by Google to determine the lifecycle outlines the major stages this project, this will be:
# - Business Understanding
#      - Define a problem
# - Data Acquisition and Understanding
#     - Data extraction
#     - Data analysis
#     - Data preparation
# - Modeling
#     - Model training
#     - Model evaluation
# - Deployment
# In this notebook we will focus on the first three items and give some recommendations for the last item.

# %%
# Importing Required Libraries 

# Web-Scrapping
from bs4 import BeautifulSoup
import urllib
import requests
import os 
from datetime import datetime, timedelta

# Data Analysis 
import pandas as pd
import numpy as np

# Visualization
import missingno as msno
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

#Config
pd.pandas.set_option('display.max_columns', None)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Business Understanding
# As we mentioned earlier our main objetive would be to identify anomalies in the transactions that ocurred with the corporate purchase of card for the Birmingham City Council what will happen if we detect anything anormal we will mail:  foi.mailbox@birmingham.gov.uk asking for additional information.

# %% [markdown]
# ## Data Acquisition and Understanding
# ### Data Extraction
# They gave us access to the [this url](https://data.birmingham.gov.uk/dataset/purchase-card-transactions) here we will find all the datasets from Apr 2014 to Jan 2018, we can then web scrap the page to obtain the distinct links and aftewards download all the related dataset, we could do it manually but it would take time each time we want to access the data, it will be harder to replicate our experiment and we would incur into a risk of downloading the information twice or skip a file. Each of the files we identify within the webpage we will then save it to our local (in case the later they change anything within their webpage or they restrict the access through webscrappers) and finally we will read each file and concatenate in a complete dataset before we start our data analysis.

# %%
url = 'https://data.birmingham.gov.uk/dataset/purchase-card-transactions'

def get_beutiful_content(url):
    url_request = requests.get(url)
    assert url_request.status_code == 200
    src = BeautifulSoup(url_request.content)
    return src

src = get_beutiful_content(url)
all_list = src.find_all('a', "resource-url-analytics")
all_xls = [tag['href'] for tag in all_list if tag['href'].find('.xls') != -1 or tag['href'].find('.csv') != -1]
print(all_xls[0],'\n',all_xls[-1])
# Out:
# https://data.birmingham.gov.uk/dataset/cf552d08-cee9-43bf-8c0f-3196a9311799/resource/b4a15ade-11b1-4c98-88a0-8cd8408212ac/download/purchasecardtransactionsapril2014.xls
#  https://data.birmingham.gov.uk/dataset/cf552d08-cee9-43bf-8c0f-3196a9311799/resource/200906b7-366c-441c-9071-ec9ab086e193/download/cusersfinainmndesktoppublish-spend-january-2018.xls

# %%
dates = ["2014-04-01", "2018-01-30"]

def create_month_year_list(dates):
    start, end = [datetime.strptime(date, "%Y-%m-%d") for date in dates]
    mlist = []
    total_months = lambda dt: dt.month + 12 * dt.year
    for tot_m in range(total_months(start)-1, total_months(end)):
        y, m = divmod(tot_m, 12)
        mlist.append(datetime(y, m+1, 1).strftime("%Y-%m"))
    return mlist

names_xls = create_month_year_list(dates)
names_xls.remove('2015-04') # this month is missing
assert len(names_xls) == len(all_xls)

# %%
path_to_save = "./data/"

def save_all_files_local(all_xls, path):
    
    for i, url_xls in enumerate(all_xls):

        file_format = url_xls[url_xls.rfind('.'):]
        save_name = path + names_xls[i] + file_format

        if file_format == '.csv':
            response = urllib.request.urlopen(url_xls)
            csv = response.read()
            with open(path + names_xls[i] + file_format, 'wb') as f:
                f.write(csv)
        else:
            urllib.request.urlretrieve(url_xls, save_name)

save_all_files_local(all_xls, path_to_save)

# %%
def get_dataset(data_path='./data/'):
    final_df = pd.DataFrame()
    local_list_xls = os.listdir(data_path) 
    for file in local_list_xls:
        if file.endswith('xls'):
            temp_df = pd.read_excel(data_path + file)
        if file.endswith('csv'):
            temp_df = pd.read_csv(data_path + file, sep=',')
        final_df = pd.concat([final_df, temp_df], axis=0, sort=True)
    return final_df

# %%
df = get_dataset()

# %% [markdown]
# ### Data Analysis
# #### Dataset general information
#
# The first thing we want to do is answer:
# * What is the shape of the dataset?
# * How many columns (features) are?
# * What are the type of features?

# %%
print(f'Data shape: {df.shape} \n')
print(f'Information of data columns:{df.info()} \n')
# Out:
# Data shape: (186060, 29)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186060 entries, 0 to 5639
# Data columns (total 29 columns):
# AGENT                 151 non-null object
# APPLICANT             151 non-null object
# Accepted              151 non-null object
# BILLING CUR CODE      88696 non-null object
# BILLING CUR CODE.1    4598 non-null object
# BILLING GROSS AMT     54229 non-null float64
# CARD NUMBER           185908 non-null object
# Category              151 non-null object
# DEV                   151 non-null object
# Directorate           169311 non-null object
# Directorate           2062 non-null object
# Directorates          9839 non-null object
# LOCATION              151 non-null object
# MERCHANT NAME         185908 non-null object
# ORIGINAL CUR          54229 non-null object
# ORIGINAL GROSS AMT    185908 non-null float64
# REFERENCE             151 non-null object
# Received_Date         151 non-null object
# TRANS CAC CODE 1      185804 non-null object
# TRANS CAC CODE 2      185673 non-null object
# TRANS CAC CODE 3      185616 non-null object
# TRANS CAC DESC 1      185804 non-null object
# TRANS CAC DESC 2      185673 non-null object
# TRANS DATE            185908 non-null datetime64[ns]
# TRANS TAX AMT         4598 non-null float64
# TRANS VAT DESC        176065 non-null object
# Unnamed: 10           3959 non-null object
# WARD                  151 non-null object
# geom                  0 non-null float64
# dtypes: datetime64[ns](1), float64(4), object(24)
# memory usage: 42.6+ MB
# Information of data columns:None

# %% [markdown]
# From this we can get the sense of the total data set, we got around 186K samples and a total of 29 columns most of them are categorical and a few numerical and last but no least a datetime column. Also, we can see that the data set has some missing values, we will explore in more detail these missing values and determined what to do with them.

# %% [markdown]
# ###### Exploring missing values

# %% [markdown]
# We will explore all the columns that have missing values, we want a nice clean dataset by the end of the exploration we will setup all the data transformations within a function.

# %%
msno.matrix(df)

# %% [markdown]
# With Missingno library we can get a graphical sense about the missing values, here we can se that there are some variables which seem that we can transform only into 1 for example all the combination of Directorate, Directorate (with a space), Directorates and Unnamed:10.
#
# Also we can see that there are varaibles that appear in all the datasets like the starting with TRANS_CAC, ORIGINAL GORSS AMT, MERCHANT NAME, CARD NUMBER and others that don't seem to report the same information from other (maybe the csv exception) like AGENT, WARD, GEOM.
#
# Let's then try to reduce to less columns for the features that are reported with a different name but are the same

# %%
df.sample(3)
# Out:
#      AGENT APPLICANT Accepted BILLING CUR CODE BILLING CUR CODE.1  \
# 769    NaN       NaN      NaN              NaN                NaN
# 1540   NaN       NaN      NaN              GBP                NaN
# 4251   NaN       NaN      NaN              GBP                NaN
#
#       BILLING GROSS AMT       CARD NUMBER Category  DEV     Directorate  \
# 769                 NaN  ************9046      NaN  NaN           CYP&F
# 1540               8.85  ************5190      NaN  NaN   CYP&F SCHOOLS
# 4251               4.15  ************0503      NaN  NaN  Local Services
#
#      Directorate  Directorates LOCATION          MERCHANT NAME ORIGINAL CUR  \
# 769           NaN          NaN      NaN         tesco pfs 5540          NaN
# 1540          NaN          NaN      NaN       cash advance fee          GBP
# 4251          NaN          NaN      NaN  cherwell valley costa          GBP
#
#       ORIGINAL GROSS AMT REFERENCE Received_Date TRANS CAC CODE 1  \
# 769                20.00       NaN           NaN             K020
# 1540                8.85       NaN           NaN             MC70
# 4251                4.15       NaN           NaN             H0R0
#
#      TRANS CAC CODE 2 TRANS CAC CODE 3         TRANS CAC DESC 1  \
# 769             RV026              A00             Vehicle Fuel
# 1540            REAXL              A00       Supplies & Sev Mic
# 4251            RUF0F              A00  Conference Fees Subs UK
#
#                             TRANS CAC DESC 2 TRANS DATE  TRANS TAX AMT  \
# 769                  Millmead Rd Ch, 52, B32 2015-10-12            NaN
# 1540                             Baskerville 2017-01-04            NaN
# 4251  Illegal Money Lending T Stds Comm Inv. 2017-01-04            NaN
#
#      TRANS VAT DESC Unnamed: 10 WARD  geom
# 769              VR         NaN  NaN   NaN
# 1540             VZ         NaN  NaN   NaN
# 4251             VR         NaN  NaN   NaN

# %%
df[~df['APPLICANT'].isna()].sample(3)
df[(~df['AGENT'].isna()) &(~df['ORIGINAL GROSS AMT'].isna())]
df[~df['APPLICANT'].isna()].sample(3)
df[(~df['APPLICANT'].isna()) &(~df['ORIGINAL GROSS AMT'].isna())]
# Out:
#                                                  AGENT  \
# 119  David Thorp Architects, 32 Springfield Road, M...
# 72   Mr Muhammad Tufail, 269 Somerville Road, Small...
# 4    K G Bramwell MCIAT, 65 Brookhus Farm Road, Wal...
#
#                                              APPLICANT    Accepted  \
# 119  Mr Rajesh Madahar,131 Cherry Orchard Road, Han...  11/01/2018
# 72   Mr Muhammed Maskeen,102 Ivor Road, Birmingham,...  12/01/2018
# 4    Mr Andrew Haslehurst,145 Lichfield Road, Four ...  11/01/2018
#
#     BILLING CUR CODE BILLING CUR CODE.1  BILLING GROSS AMT CARD NUMBER  \
# 119              NaN                NaN                NaN         NaN
# 72               NaN                NaN                NaN         NaN
# 4                NaN                NaN                NaN         NaN
#
#         Category                                                DEV  \
# 119  Householder  Erection of single storey front and two storey...
# 72   Householder           Erection of single storey rear extension
# 4    Householder    Erection of two storey side and rear extensions
#
#     Directorate Directorate  Directorates  \
# 119         NaN          NaN          NaN
# 72          NaN          NaN          NaN
# 4           NaN          NaN          NaN
#
#                                               LOCATION MERCHANT NAME  \
# 119  131 Cherry Orchard Road, Handsworth, Birmingha...           NaN
# 72       102 Ivor Road, Sparkhill, Birmingham, B11 4NX           NaN
# 4    145 Lichfield Road, Four Oaks, Sutton Coldfiel...           NaN
#
#     ORIGINAL CUR  ORIGINAL GROSS AMT      REFERENCE Received_Date  \
# 119          NaN                 NaN  2018/00038/PA    04/01/2018
# 72           NaN                 NaN  2018/00235/PA    12/01/2018
# 4            NaN                 NaN  2018/00191/PA    11/01/2018
#
#     TRANS CAC CODE 1 TRANS CAC CODE 2 TRANS CAC CODE 3 TRANS CAC DESC 1  \
# 119              NaN              NaN              NaN              NaN
# 72               NaN              NaN              NaN              NaN
# 4                NaN              NaN              NaN              NaN
#
#     TRANS CAC DESC 2 TRANS DATE  TRANS TAX AMT TRANS VAT DESC Unnamed: 10  \
# 119              NaN        NaT            NaN            NaN         NaN
# 72               NaN        NaT            NaN            NaN         NaN
# 4                NaN        NaT            NaN            NaN         NaN
#
#                  WARD  geom
# 119   Handsworth Wood   NaN
# 72        Springfield   NaN
# 4    Sutton Four Oaks   NaN
# Empty DataFrame
# Columns: [AGENT, APPLICANT, Accepted, BILLING CUR CODE, BILLING CUR CODE.1, BILLING GROSS AMT, CARD NUMBER, Category, DEV, Directorate, Directorate , Directorates, LOCATION, MERCHANT NAME, ORIGINAL CUR, ORIGINAL GROSS AMT, REFERENCE, Received_Date, TRANS CAC CODE 1, TRANS CAC CODE 2, TRANS CAC CODE 3, TRANS CAC DESC 1, TRANS CAC DESC 2, TRANS DATE, TRANS TAX AMT, TRANS VAT DESC, Unnamed: 10, WARD, geom]
# Index: []
#                                                  AGENT  \
# 76   Umer Surveys, 469B Coventry Road, Small Heath,...
# 117  MCJ Solutions, 18 Bridle Lane, Sutton Coldfiel...
# 39   Mr Hanif Ghumra, 733 Walsall Road, Great Barr,...
#
#                                              APPLICANT    Accepted  \
# 76   Mrs Rafana Shaheen,30 Castleford Road, Sparkhi...  17/01/2018
# 117  Ms Gurpreet Dhadday,1 Trickley Drive, Sutton C...  10/01/2018
# 39   Mr F Khan,53 Kingsbury Road, Erdington, Birmin...  15/01/2018
#
#     BILLING CUR CODE BILLING CUR CODE.1  BILLING GROSS AMT CARD NUMBER  \
# 76               NaN                NaN                NaN         NaN
# 117              NaN                NaN                NaN         NaN
# 39               NaN                NaN                NaN         NaN
#
#           Category                                                DEV  \
# 76     Householder   Erection of two and single storey side extension
# 117    Householder          Erection of single storey rear extension.
# 39   Change of Use  Retention of use as a house in multiple occupa...
#
#     Directorate Directorate  Directorates  \
# 76          NaN          NaN          NaN
# 117         NaN          NaN          NaN
# 39          NaN          NaN          NaN
#
#                                               LOCATION MERCHANT NAME  \
# 76   1 Dryden Grove, Acocks Green, Birmingham, B27 7QW           NaN
# 117  1 Trickley Drive, Sutton Coldfield, Birmingham...           NaN
# 39   53 Kingsbury Road, Erdington, Birmingham, B24 8QG           NaN
#
#     ORIGINAL CUR  ORIGINAL GROSS AMT      REFERENCE Received_Date  \
# 76           NaN                 NaN  2018/00327/PA    16/01/2018
# 117          NaN                 NaN  2018/00060/PA    05/01/2018
# 39           NaN                 NaN  2018/00353/PA    15/01/2018
#
#     TRANS CAC CODE 1 TRANS CAC CODE 2 TRANS CAC CODE 3 TRANS CAC DESC 1  \
# 76               NaN              NaN              NaN              NaN
# 117              NaN              NaN              NaN              NaN
# 39               NaN              NaN              NaN              NaN
#
#     TRANS CAC DESC 2 TRANS DATE  TRANS TAX AMT TRANS VAT DESC Unnamed: 10  \
# 76               NaN        NaT            NaN            NaN         NaN
# 117              NaN        NaT            NaN            NaN         NaN
# 39               NaN        NaT            NaN            NaN         NaN
#
#                WARD  geom
# 76     Acocks Green   NaN
# 117  Sutton Trinity   NaN
# 39           Tyburn   NaN
# Empty DataFrame
# Columns: [AGENT, APPLICANT, Accepted, BILLING CUR CODE, BILLING CUR CODE.1, BILLING GROSS AMT, CARD NUMBER, Category, DEV, Directorate, Directorate , Directorates, LOCATION, MERCHANT NAME, ORIGINAL CUR, ORIGINAL GROSS AMT, REFERENCE, Received_Date, TRANS CAC CODE 1, TRANS CAC CODE 2, TRANS CAC CODE 3, TRANS CAC DESC 1, TRANS CAC DESC 2, TRANS DATE, TRANS TAX AMT, TRANS VAT DESC, Unnamed: 10, WARD, geom]
# Index: []

# %%
df.notnull().sum()
# Out:
# AGENT                    151
# APPLICANT                151
# Accepted                 151
# BILLING CUR CODE       88696
# BILLING CUR CODE.1      4598
# BILLING GROSS AMT      54229
# CARD NUMBER           185908
# Category                 151
# DEV                      151
# Directorate           169311
# Directorate             2062
# Directorates            9839
# LOCATION                 151
# MERCHANT NAME         185908
# ORIGINAL CUR           54229
# ORIGINAL GROSS AMT    185908
# REFERENCE                151
# Received_Date            151
# TRANS CAC CODE 1      185804
# TRANS CAC CODE 2      185673
# TRANS CAC CODE 3      185616
# TRANS CAC DESC 1      185804
# TRANS CAC DESC 2      185673
# TRANS DATE            185908
# TRANS TAX AMT           4598
# TRANS VAT DESC        176065
# Unnamed: 10             3959
# WARD                     151
# geom                       0
# dtype: int64

# %% [markdown]
# It appears that there was a file which reported other format with some specific information, hence we will drop 151 records from this file.

# %%
df[~df['Directorate'].isna()]['Directorate'].sample(3)
df[~df['Directorate '].isna()]['Directorate '].sample(3)
df[~df['Directorates'].isna()]['Directorates'].sample(3)
df[~df['Unnamed: 10'].isna()]['Unnamed: 10'].sample(3)
# Out:
# 335     Corporate Resources
# 3877         Local Services
# 3377          CYP&F SCHOOLS
# Name: Directorate, dtype: object
# 1527    Local Services
# 738              CYP&F
# 1311       DEVELOPMENT
# Name: Directorate , dtype: object
# 3214    Local Services
# 2312     CYP&F SCHOOLS
# 5017    Local Services
# Name: Directorates, dtype: object
# 2546          CYP&F SCHOOLS
# 15      Adult & Communities
# 2361          CYP&F SCHOOLS
# Name: Unnamed: 10, dtype: object

# %% [markdown]
# As we assumed the Directorate, Directorate (with a space), Directorates and Unnamed:10 are all the same column, for that we will group them in just one column.

# %%
df[(df['BILLING CUR CODE']!=df['BILLING CUR CODE.1']) & (~df['BILLING CUR CODE.1'].isna())].shape
# Out:
# (0, 29)

# %% [markdown]
# Also the 'BILLING CUR CODE' and 'BILLING CUR CODE.1' appear to be the same, hence we will drop the 'BILLING CUR CODE.1' and leave only one

# %%
df[~(df['TRANS TAX AMT'].isna())]
# Out:
#      AGENT APPLICANT Accepted BILLING CUR CODE BILLING CUR CODE.1  \
# 0      NaN       NaN      NaN              GBP                GBP
# 1      NaN       NaN      NaN              GBP                GBP
# 2      NaN       NaN      NaN              GBP                GBP
# 3      NaN       NaN      NaN              GBP                GBP
# 4      NaN       NaN      NaN              GBP                GBP
# 5      NaN       NaN      NaN              GBP                GBP
# 6      NaN       NaN      NaN              GBP                GBP
# 7      NaN       NaN      NaN              GBP                GBP
# 8      NaN       NaN      NaN              GBP                GBP
# 9      NaN       NaN      NaN              GBP                GBP
# 10     NaN       NaN      NaN              GBP                GBP
# 11     NaN       NaN      NaN              GBP                GBP
# 12     NaN       NaN      NaN              GBP                GBP
# 13     NaN       NaN      NaN              GBP                GBP
# 14     NaN       NaN      NaN              GBP                GBP
# 15     NaN       NaN      NaN              GBP                GBP
# 16     NaN       NaN      NaN              GBP                GBP
# 17     NaN       NaN      NaN              GBP                GBP
# 18     NaN       NaN      NaN              GBP                GBP
# 19     NaN       NaN      NaN              GBP                GBP
# 20     NaN       NaN      NaN              GBP                GBP
# 21     NaN       NaN      NaN              GBP                GBP
# 22     NaN       NaN      NaN              GBP                GBP
# 23     NaN       NaN      NaN              GBP                GBP
# 24     NaN       NaN      NaN              GBP                GBP
# 25     NaN       NaN      NaN              GBP                GBP
# 26     NaN       NaN      NaN              GBP                GBP
# 27     NaN       NaN      NaN              GBP                GBP
# 28     NaN       NaN      NaN              GBP                GBP
# 29     NaN       NaN      NaN              GBP                GBP
# ...    ...       ...      ...              ...                ...
# 4568   NaN       NaN      NaN              GBP                GBP
# 4569   NaN       NaN      NaN              GBP                GBP
# 4570   NaN       NaN      NaN              GBP                GBP
# 4571   NaN       NaN      NaN              GBP                GBP
# 4572   NaN       NaN      NaN              GBP                GBP
# 4573   NaN       NaN      NaN              GBP                GBP
# 4574   NaN       NaN      NaN              GBP                GBP
# 4575   NaN       NaN      NaN              GBP                GBP
# 4576   NaN       NaN      NaN              GBP                GBP
# 4577   NaN       NaN      NaN              GBP                GBP
# 4578   NaN       NaN      NaN              GBP                GBP
# 4579   NaN       NaN      NaN              GBP                GBP
# 4580   NaN       NaN      NaN              GBP                GBP
# 4581   NaN       NaN      NaN              GBP                GBP
# 4582   NaN       NaN      NaN              GBP                GBP
# 4583   NaN       NaN      NaN              GBP                GBP
# 4584   NaN       NaN      NaN              GBP                GBP
# 4585   NaN       NaN      NaN              GBP                GBP
# 4586   NaN       NaN      NaN              GBP                GBP
# 4587   NaN       NaN      NaN              GBP                GBP
# 4588   NaN       NaN      NaN              GBP                GBP
# 4589   NaN       NaN      NaN              GBP                GBP
# 4590   NaN       NaN      NaN              GBP                GBP
# 4591   NaN       NaN      NaN              GBP                GBP
# 4592   NaN       NaN      NaN              GBP                GBP
# 4593   NaN       NaN      NaN              GBP                GBP
# 4594   NaN       NaN      NaN              GBP                GBP
# 4595   NaN       NaN      NaN              GBP                GBP
# 4596   NaN       NaN      NaN              GBP                GBP
# 4597   NaN       NaN      NaN              GBP                GBP
#
#       BILLING GROSS AMT       CARD NUMBER Category  DEV          Directorate  \
# 0                 50.00  ************5804      NaN  NaN  Adult & Communities
# 1                 60.01  ************5804      NaN  NaN  Adult & Communities
# 2                 59.00  ************2823      NaN  NaN  Adult & Communities
# 3                 59.72  ************2823      NaN  NaN  Adult & Communities
# 4                 67.06  ************7214      NaN  NaN  Adult & Communities
# 5                 61.33  ************7214      NaN  NaN  Adult & Communities
# 6                 57.14  ************7214      NaN  NaN  Adult & Communities
# 7                 66.01  ************7214      NaN  NaN  Adult & Communities
# 8                 75.00  ************8998      NaN  NaN  Adult & Communities
# 9                 75.00  ************8998      NaN  NaN  Adult & Communities
# 10                75.00  ************8998      NaN  NaN  Adult & Communities
# 11                75.00  ************8998      NaN  NaN  Adult & Communities
# 12                75.00  ************8998      NaN  NaN  Adult & Communities
# 13                64.13  ************5463      NaN  NaN  Adult & Communities
# 14                83.45  ************5463      NaN  NaN  Adult & Communities
# 15                54.65  ************5463      NaN  NaN  Adult & Communities
# 16                64.19  ************5463      NaN  NaN  Adult & Communities
# 17                54.61  ************5463      NaN  NaN  Adult & Communities
# 18                80.02  ************5463      NaN  NaN  Adult & Communities
# 19                74.64  ************5463      NaN  NaN  Adult & Communities
# 20                61.94  ************3668      NaN  NaN  Adult & Communities
# 21                85.00  ************3668      NaN  NaN  Adult & Communities
# 22                61.01  ************3668      NaN  NaN  Adult & Communities
# 23                70.70  ************8061      NaN  NaN  Adult & Communities
# 24                70.25  ************8061      NaN  NaN  Adult & Communities
# 25                55.00  ************8061      NaN  NaN  Adult & Communities
# 26                69.19  ************8061      NaN  NaN  Adult & Communities
# 27                68.32  ************4985      NaN  NaN  Adult & Communities
# 28                60.82  ************4985      NaN  NaN  Adult & Communities
# 29                80.96  ************4985      NaN  NaN  Adult & Communities
# ...                 ...               ...      ...  ...                  ...
# 4568              11.88  ************0407      NaN  NaN       Local Services
# 4569              58.95  ************0407      NaN  NaN       Local Services
# 4570              11.21  ************0595      NaN  NaN       Local Services
# 4571              71.00  ************0595      NaN  NaN       Local Services
# 4572              73.20  ************0595      NaN  NaN       Local Services
# 4573              76.00  ************0595      NaN  NaN       Local Services
# 4574              68.68  ************0595      NaN  NaN       Local Services
# 4575               5.90  ************9707      NaN  NaN       Local Services
# 4576               5.90  ************9707      NaN  NaN       Local Services
# 4577               5.85  ************9707      NaN  NaN       Local Services
# 4578               6.95  ************9707      NaN  NaN       Local Services
# 4579              72.06  ************9707      NaN  NaN       Local Services
# 4580               5.85  ************9707      NaN  NaN       Local Services
# 4581             248.37  ************9707      NaN  NaN       Local Services
# 4582             248.36  ************9707      NaN  NaN       Local Services
# 4583              -6.95  ************9707      NaN  NaN       Local Services
# 4584               5.10  ************9707      NaN  NaN       Local Services
# 4585              70.00  ************9707      NaN  NaN       Local Services
# 4586              18.20  ************8021      NaN  NaN       Local Services
# 4587              80.78  ************8527      NaN  NaN       Local Services
# 4588               2.37  ************8527      NaN  NaN       Local Services
# 4589              86.04  ************6790      NaN  NaN       Local Services
# 4590              63.36  ************4599      NaN  NaN       Local Services
# 4591           19398.82  ************6583      NaN  NaN  Corporate Resources
# 4592           14156.41  ************6583      NaN  NaN  Corporate Resources
# 4593           22885.25  ************6583      NaN  NaN  Corporate Resources
# 4594           29596.54  ************6583      NaN  NaN  Corporate Resources
# 4595           19625.42  ************6583      NaN  NaN  Corporate Resources
# 4596             240.00  ************7758      NaN  NaN  Corporate Resources
# 4597             112.91  ************7758      NaN  NaN  Corporate Resources
#
#      Directorate  Directorates LOCATION           MERCHANT NAME ORIGINAL CUR  \
# 0             NaN          NaN      NaN            mrh six ways          GBP
# 1             NaN          NaN      NaN      beeches road servi          GBP
# 2             NaN          NaN      NaN         shell kings 587          GBP
# 3             NaN          NaN      NaN         shell kings 587          GBP
# 4             NaN          NaN      NaN        texaco ash motor          GBP
# 5             NaN          NaN      NaN        texaco ash motor          GBP
# 6             NaN          NaN      NaN        texaco ash motor          GBP
# 7             NaN          NaN      NaN        texaco ash motor          GBP
# 8             NaN          NaN      NaN      hmcourts-service.g          GBP
# 9             NaN          NaN      NaN      hmcourts-service.g          GBP
# 10            NaN          NaN      NaN      hmcourts-service.g          GBP
# 11            NaN          NaN      NaN      hmcourts-service.g          GBP
# 12            NaN          NaN      NaN      hmcourts-service.g          GBP
# 13            NaN          NaN      NaN       malthurst limited          GBP
# 14            NaN          NaN      NaN       malthurst limited          GBP
# 15            NaN          NaN      NaN       malthurst limited          GBP
# 16            NaN          NaN      NaN       malthurst limited          GBP
# 17            NaN          NaN      NaN       malthurst limited          GBP
# 18            NaN          NaN      NaN       malthurst limited          GBP
# 19            NaN          NaN      NaN       malthurst limited          GBP
# 20            NaN          NaN      NaN       malthurst limited          GBP
# 21            NaN          NaN      NaN       malthurst limited          GBP
# 22            NaN          NaN      NaN       malthurst limited          GBP
# 23            NaN          NaN      NaN      malthurst petroleu          GBP
# 24            NaN          NaN      NaN      perry barr service          GBP
# 25            NaN          NaN      NaN      perry barr service          GBP
# 26            NaN          NaN      NaN      malthurst petroleu          GBP
# 27            NaN          NaN      NaN   penns lane sf connect          GBP
# 28            NaN          NaN      NaN   penns lane sf connect          GBP
# 29            NaN          NaN      NaN   penns lane sf connect          GBP
# ...           ...          ...      ...                     ...          ...
# 4568          NaN          NaN      NaN            amazon.co.uk          GBP
# 4569          NaN          NaN      NaN         wickes building          GBP
# 4570          NaN          NaN      NaN  tesco pay at pump 4203          GBP
# 4571          NaN          NaN      NaN         shell sparkhill          GBP
# 4572          NaN          NaN      NaN  tesco pay at pump 4203          GBP
# 4573          NaN          NaN      NaN          tesco pfs 4203          GBP
# 4574          NaN          NaN      NaN  tesco pay at pump 4203          GBP
# 4575          NaN          NaN      NaN                 m6 toll          GBP
# 4576          NaN          NaN      NaN                 m6 toll          GBP
# 4577          NaN          NaN      NaN      town green stn t/o          GBP
# 4578          NaN          NaN      NaN               argos ltd          GBP
# 4579          NaN          NaN      NaN   amazon uk marketplace          GBP
# 4580          NaN          NaN      NaN      town green stn t/o          GBP
# 4581          NaN          NaN      NaN        amazon uk retail          GBP
# 4582          NaN          NaN      NaN   amazon uk marketplace          GBP
# 4583          NaN          NaN      NaN            argos direct          GBP
# 4584          NaN          NaN      NaN      town green stn t/o          GBP
# 4585          NaN          NaN      NaN               argos ltd          GBP
# 4586          NaN          NaN      NaN      vmb news superstor          GBP
# 4587          NaN          NaN      NaN          tesco pfs 3953          GBP
# 4588          NaN          NaN      NaN          tesco pfs 3953          GBP
# 4589          NaN          NaN      NaN          tesco pfs 4203          GBP
# 4590          NaN          NaN      NaN         shell four oaks          GBP
# 4591          NaN          NaN      NaN  the furnishing service          GBP
# 4592          NaN          NaN      NaN  the furnishing service          GBP
# 4593          NaN          NaN      NaN  the furnishing service          GBP
# 4594          NaN          NaN      NaN  the furnishing service          GBP
# 4595          NaN          NaN      NaN  the furnishing service          GBP
# 4596          NaN          NaN      NaN   eb community health s          GBP
# 4597          NaN          NaN      NaN         www.argos.co.uk          GBP
#
#       ORIGINAL GROSS AMT REFERENCE Received_Date TRANS CAC CODE 1  \
# 0                  50.00       NaN           NaN             K020
# 1                  60.01       NaN           NaN             K020
# 2                  59.00       NaN           NaN             K020
# 3                  59.72       NaN           NaN             K020
# 4                  67.06       NaN           NaN             K020
# 5                  61.33       NaN           NaN             K020
# 6                  57.14       NaN           NaN             K020
# 7                  66.01       NaN           NaN             K020
# 8                  75.00       NaN           NaN             MC70
# 9                  75.00       NaN           NaN             MC70
# 10                 75.00       NaN           NaN             MC70
# 11                 75.00       NaN           NaN             MC70
# 12                 75.00       NaN           NaN             MC70
# 13                 64.13       NaN           NaN             K020
# 14                 83.45       NaN           NaN             K020
# 15                 54.65       NaN           NaN             K020
# 16                 64.19       NaN           NaN             K020
# 17                 54.61       NaN           NaN             K020
# 18                 80.02       NaN           NaN             K020
# 19                 74.64       NaN           NaN             K020
# 20                 61.94       NaN           NaN             K020
# 21                 85.00       NaN           NaN             K020
# 22                 61.01       NaN           NaN             K020
# 23                 70.70       NaN           NaN             K020
# 24                 70.25       NaN           NaN             K020
# 25                 55.00       NaN           NaN             K020
# 26                 69.19       NaN           NaN             K020
# 27                 68.32       NaN           NaN             K020
# 28                 60.82       NaN           NaN             K020
# 29                 80.96       NaN           NaN             K020
# ...                  ...       ...           ...              ...
# 4568               11.88       NaN           NaN             L100
# 4569               58.95       NaN           NaN             J030
# 4570               11.21       NaN           NaN             K020
# 4571               71.00       NaN           NaN             K020
# 4572               73.20       NaN           NaN             K020
# 4573               76.00       NaN           NaN             K020
# 4574               68.68       NaN           NaN             K020
# 4575                5.90       NaN           NaN             K240
# 4576                5.90       NaN           NaN             K240
# 4577                5.85       NaN           NaN             K210
# 4578                6.95       NaN           NaN             L6C0
# 4579               72.06       NaN           NaN             L100
# 4580                5.85       NaN           NaN             K210
# 4581              248.37       NaN           NaN             H220
# 4582              248.36       NaN           NaN             H220
# 4583               -6.95       NaN           NaN             L6C0
# 4584                5.10       NaN           NaN             K210
# 4585               70.00       NaN           NaN             L5H0
# 4586               18.20       NaN           NaN             L000
# 4587               80.78       NaN           NaN             K020
# 4588                2.37       NaN           NaN             K020
# 4589               86.04       NaN           NaN             K020
# 4590               63.36       NaN           NaN             K020
# 4591            19398.82       NaN           NaN             L100
# 4592            14156.41       NaN           NaN             L100
# 4593            22885.25       NaN           NaN             L100
# 4594            29596.54       NaN           NaN             L100
# 4595            19625.42       NaN           NaN             L100
# 4596              240.00       NaN           NaN             L100
# 4597              112.91       NaN           NaN             L100
#
#      TRANS CAC CODE 2 TRANS CAC CODE 3      TRANS CAC DESC 1  \
# 0               RVA12              A00          Vehicle Fuel
# 1               RVA12              A00          Vehicle Fuel
# 2               RV191              A00          Vehicle Fuel
# 3               RV191              A00          Vehicle Fuel
# 4               RV12T              A00          Vehicle Fuel
# 5               RV12T              A00          Vehicle Fuel
# 6               RV12T              A00          Vehicle Fuel
# 7               RV12T              A00          Vehicle Fuel
# 8               RV3T0              A00    Supplies & Sev Mic
# 9               RV3T0              A00    Supplies & Sev Mic
# 10              RV3T0              A00    Supplies & Sev Mic
# 11              RV3T0              A00    Supplies & Sev Mic
# 12              RV3T0              A00    Supplies & Sev Mic
# 13              RV18P              A00          Vehicle Fuel
# 14              RV18P              A00          Vehicle Fuel
# 15              RV18P              A00          Vehicle Fuel
# 16              RV18P              A00          Vehicle Fuel
# 17              RV18P              A00          Vehicle Fuel
# 18              RV18P              A00          Vehicle Fuel
# 19              RV18P              A00          Vehicle Fuel
# 20              RV18P              A00          Vehicle Fuel
# 21              RV18P              A00          Vehicle Fuel
# 22              RV18P              A00          Vehicle Fuel
# 23              RVA12              A00          Vehicle Fuel
# 24              RVA12              A00          Vehicle Fuel
# 25              RVA12              A00          Vehicle Fuel
# 26              RVA12              A00          Vehicle Fuel
# 27              RV18N              A00          Vehicle Fuel
# 28              RV18N              A00          Vehicle Fuel
# 29              RV18N              A00          Vehicle Fuel
# ...               ...              ...                   ...
# 4568            RUA21              A00     Equip Operational
# 4569            RUA21              A00  Bldg RM Departmental
# 4570            RLC01              A00          Vehicle Fuel
# 4571            RLC01              A00          Vehicle Fuel
# 4572            RLC01              A00          Vehicle Fuel
# 4573            RLC01              A00          Vehicle Fuel
# 4574            RLC01              A00          Vehicle Fuel
# 4575            RUF0F              A00     Ttavel Other (UK)
# 4576            RUF0F              A00     Ttavel Other (UK)
# 4577            RUF0F              A00       Travel Bus/Rail
# 4578            RUF0F              A00      Witness Expenses
# 4579            RUF0F              A00     Equip Operational
# 4580            RUF0F              A00       Travel Bus/Rail
# 4581            RUF0F              A00  Training EquipMat'ls
# 4582            RUF0F              A00  Training EquipMat'ls
# 4583            RUF0F              A00      Witness Expenses
# 4584            RUF0F              A00       Travel Bus/Rail
# 4585            RUF0F              A00  Promotions/Marketing
# 4586            RLC49              A00  N'Papers&Periodicals
# 4587            RHB03              A00          Vehicle Fuel
# 4588            RHB03              A00          Vehicle Fuel
# 4589            RHEE7              A00          Vehicle Fuel
# 4590            RHNCA              A00          Vehicle Fuel
# 4591            RYB5F              A00     Equip Operational
# 4592            RYB5F              A00     Equip Operational
# 4593            RYB5F              A00     Equip Operational
# 4594            RYB5F              A00     Equip Operational
# 4595            RYB5F              A00     Equip Operational
# 4596            RBF22              A00     Equip Operational
# 4597            RBF22              A00     Equip Operational
#
#                             TRANS CAC DESC 2 TRANS DATE  TRANS TAX AMT  \
# 0                       Enablement Tyburn Rd 2017-09-15           8.33
# 1                       Enablement Tyburn Rd 2017-09-22          10.00
# 2                         Moseley Day Centre 2017-09-18           9.83
# 3                         Moseley Day Centre 2017-09-29           9.95
# 4     Shakti Elders Dce, 73 Conybere St, B12 2017-09-08          11.18
# 5     Shakti Elders Dce, 73 Conybere St, B12 2017-09-13          10.22
# 6     Shakti Elders Dce, 73 Conybere St, B12 2017-09-20           9.52
# 7     Shakti Elders Dce, 73 Conybere St, B12 2017-09-27          11.00
# 8            Mental Health Management Budget 2017-09-05           0.00
# 9            Mental Health Management Budget 2017-09-08           0.00
# 10           Mental Health Management Budget 2017-09-15           0.00
# 11           Mental Health Management Budget 2017-09-18           0.00
# 12           Mental Health Management Budget 2017-09-20           0.00
# 13                        Hockley Day Centre 2017-09-06          10.69
# 14                        Hockley Day Centre 2017-09-11          13.91
# 15                        Hockley Day Centre 2017-09-11           9.11
# 16                        Hockley Day Centre 2017-09-15          10.70
# 17                        Hockley Day Centre 2017-09-27           9.10
# 18                        Hockley Day Centre 2017-10-02           0.00
# 19                        Hockley Day Centre 2017-10-02           0.00
# 20                        Hockley Day Centre 2017-09-05          10.32
# 21                        Hockley Day Centre 2017-09-28          14.17
# 22                        Hockley Day Centre 2017-09-28          10.17
# 23                      Enablement Tyburn Rd 2017-09-06          11.78
# 24                      Enablement Tyburn Rd 2017-09-11          11.71
# 25                      Enablement Tyburn Rd 2017-09-18           9.17
# 26                      Enablement Tyburn Rd 2017-09-27          11.53
# 27                         Ebrook Day Centre 2017-09-07          11.39
# 28                         Ebrook Day Centre 2017-09-08          10.14
# 29                         Ebrook Day Centre 2017-09-20          13.49
# ...                                      ...        ...            ...
# 4568             Handsworth Cemetery General 2017-09-28           0.00
# 4569             Handsworth Cemetery General 2017-10-02           9.83
# 4570                             Directorate 2017-09-06           1.87
# 4571                             Directorate 2017-09-08          11.83
# 4572                             Directorate 2017-09-12          12.20
# 4573                             Directorate 2017-09-25          12.67
# 4574                             Directorate 2017-09-27          11.45
# 4575  Illegal Money Lending T Stds Comm Inv. 2017-09-05           0.98
# 4576  Illegal Money Lending T Stds Comm Inv. 2017-09-05           0.98
# 4577  Illegal Money Lending T Stds Comm Inv. 2017-09-06           0.00
# 4578  Illegal Money Lending T Stds Comm Inv. 2017-09-08           0.00
# 4579  Illegal Money Lending T Stds Comm Inv. 2017-09-11           0.00
# 4580  Illegal Money Lending T Stds Comm Inv. 2017-09-12           0.00
# 4581  Illegal Money Lending T Stds Comm Inv. 2017-09-12           0.00
# 4582  Illegal Money Lending T Stds Comm Inv. 2017-09-12           0.00
# 4583  Illegal Money Lending T Stds Comm Inv. 2017-09-14           0.00
# 4584  Illegal Money Lending T Stds Comm Inv. 2017-09-21           0.00
# 4585  Illegal Money Lending T Stds Comm Inv. 2017-09-28          11.67
# 4586                                Bookfund 2017-09-12           0.00
# 4587                        Erd'ton Hsg Mgmt 2017-09-04          13.46
# 4588                        Erd'ton Hsg Mgmt 2017-09-04           0.40
# 4589           Ladywood CBH05 Neigh C'takers 2017-09-26          14.34
# 4590                                Careline 2017-09-28          10.56
# 4591                             Social Fund 2017-09-01        3233.14
# 4592                             Social Fund 2017-09-07        2359.40
# 4593                             Social Fund 2017-09-07        3814.21
# 4594                             Social Fund 2017-09-07        4932.76
# 4595                             Social Fund 2017-09-29        3270.90
# 4596                     Pensions & Payments 2017-09-21           0.00
# 4597                     Pensions & Payments 2017-10-02           0.00
#
#      TRANS VAT DESC Unnamed: 10 WARD  geom
# 0                VR         NaN  NaN   NaN
# 1                VR         NaN  NaN   NaN
# 2                VR         NaN  NaN   NaN
# 3                VR         NaN  NaN   NaN
# 4                VR         NaN  NaN   NaN
# 5                VR         NaN  NaN   NaN
# 6                VR         NaN  NaN   NaN
# 7                VR         NaN  NaN   NaN
# 8                VZ         NaN  NaN   NaN
# 9                VZ         NaN  NaN   NaN
# 10               VZ         NaN  NaN   NaN
# 11               VZ         NaN  NaN   NaN
# 12               VZ         NaN  NaN   NaN
# 13               VR         NaN  NaN   NaN
# 14               VR         NaN  NaN   NaN
# 15               VR         NaN  NaN   NaN
# 16               VR         NaN  NaN   NaN
# 17               VR         NaN  NaN   NaN
# 18               VR         NaN  NaN   NaN
# 19               VR         NaN  NaN   NaN
# 20               VR         NaN  NaN   NaN
# 21               VR         NaN  NaN   NaN
# 22               VR         NaN  NaN   NaN
# 23               VR         NaN  NaN   NaN
# 24               VR         NaN  NaN   NaN
# 25               VR         NaN  NaN   NaN
# 26               VR         NaN  NaN   NaN
# 27               VR         NaN  NaN   NaN
# 28               VR         NaN  NaN   NaN
# 29               VR         NaN  NaN   NaN
# ...             ...         ...  ...   ...
# 4568             VZ         NaN  NaN   NaN
# 4569             VR         NaN  NaN   NaN
# 4570             VR         NaN  NaN   NaN
# 4571             VR         NaN  NaN   NaN
# 4572             VR         NaN  NaN   NaN
# 4573             VR         NaN  NaN   NaN
# 4574             VR         NaN  NaN   NaN
# 4575             VR         NaN  NaN   NaN
# 4576             VR         NaN  NaN   NaN
# 4577             VZ         NaN  NaN   NaN
# 4578             VZ         NaN  NaN   NaN
# 4579             VZ         NaN  NaN   NaN
# 4580             VZ         NaN  NaN   NaN
# 4581             VZ         NaN  NaN   NaN
# 4582             VZ         NaN  NaN   NaN
# 4583             VZ         NaN  NaN   NaN
# 4584             VZ         NaN  NaN   NaN
# 4585             VR         NaN  NaN   NaN
# 4586             VZ         NaN  NaN   NaN
# 4587             VR         NaN  NaN   NaN
# 4588             VR         NaN  NaN   NaN
# 4589             VR         NaN  NaN   NaN
# 4590             VR         NaN  NaN   NaN
# 4591             VR         NaN  NaN   NaN
# 4592             VR         NaN  NaN   NaN
# 4593             VR         NaN  NaN   NaN
# 4594             VR         NaN  NaN   NaN
# 4595             VR         NaN  NaN   NaN
# 4596             VZ         NaN  NaN   NaN
# 4597             VR         NaN  NaN   NaN
#
# [4598 rows x 29 columns]

# %%
temp = df[~(df['TRANS TAX AMT'].isna())]
(temp['TRANS TAX AMT']/temp['ORIGINAL GROSS AMT']).round(2).value_counts()
# Out:
# 0.00    2230
# 0.17    1795
# 0.15     120
# 0.14     113
# 0.13     105
# 0.05      96
# 0.16      60
# 0.12      26
# 0.03      10
# 0.02       8
# 0.01       7
# 0.04       6
# 0.06       4
# 0.08       4
# 0.09       4
# 0.11       4
# 0.07       3
# 0.20       3
# dtype: int64

# %% [markdown]
# There isn't any logic we could apply to 'TRANS TAX AMT' for the other columns that isn't populated sometimes is 0 and another times is between 0.01 and 0.17, furthermore the tax is relative to the type of transaction and regulation of the country. Being that said we will not dive into that and drop the column

# %%
cols_to_drop = ['AGENT',
                 'APPLICANT',
                 'Accepted',
                 'Category',
                 'DEV',
                 'LOCATION',
                 'REFERENCE',
                 'Received_Date',
                 'WARD',
                 'geom', 
                 'Directorate ',
                 'Directorates',
                 'Unnamed: 10',
                 'BILLING CUR CODE.1',
                'TRANS TAX AMT']


def drop_and_group(df):
    print(f'Original shape: {df.shape}')
    df['Directorate'] = df['Directorate'].fillna(df['Directorate '])
    df['Directorate'] = df['Directorate'].fillna(df['Directorates'])
    df['Directorate'] = df['Directorate'].fillna(df['Unnamed: 10'])
    df = df.drop(columns = cols_to_drop)
    df = df.dropna(how='all')
    print(f'Modified shape: {df.shape}')
    return df 


df = drop_and_group(df)
msno.matrix(df)
# Out:
# Original shape: (186060, 29)
# Modified shape: (185909, 14)
